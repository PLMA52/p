# %%
import pandas as pd
Location = "datasets/algebradata.csv"

df = pd.read_csv(Location)

df.head()
# Out:
#      Fname     Lname Gender Grade  Hours of Study
# 0     Mary  Ettienne      F     B              16
# 1  Charles    Looner      M     F               8
# 2    Betty  Franklin      F     A              24
# 3    Roger   Withers      M     C               5
# 4     John   Mulgrew      M     A               5

# %%
# Number of Student with a grade of C or higher
df.loc[df['Grade']>='C'].count()
# Out:
# Fname             505
# Lname             505
# Gender            505
# Grade             505
# Hours of Study    505
# dtype: int64

# %%
# Number of rows
df
# Out:
#         Fname      Lname Gender Grade  Hours of Study
# 0        Mary   Ettienne      F     B              16
# 1     Charles     Looner      M     F               8
# 2       Betty   Franklin      F     A              24
# 3       Roger    Withers      M     C               5
# 4        John    Mulgrew      M     A               5
# 5        Jada   Isaacson      F     C              30
# 6        John     Carter      M     C              17
# 7      August     Carter      F     C              11
# 8       Karen     Looner      F     A              12
# 9         Sam   Walters       M     D              24
# 10       Mary       Kane      F     C              23
# 11      Paula    Mulgrew      F     D              17
# 12   Samantha  Henderson      F     B              22
# 13       Adam     Vaughn      M     B               7
# 14      Peter      Sears      M     C              18
# 15     Denise       Rose      F     A              19
# ...

# %%
# A) %age of students with a passing grade
# 505/999 = 50.55%

# %%
# C) Average hours of study for all students
df['Hours of Study'].mean()
# Out:
# 15.115115115115115

# %%
# D) Average hours of study for students with a passing grade
df.loc[df['Grade']>='C' , (['Hours of Study'])].mean()
# Out:
# Hours of Study    13.156436
# dtype: float64
